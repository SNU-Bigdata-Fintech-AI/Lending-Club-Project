# %% [markdown]
# ### 순서
# ##### 1. 종속변수 라벨링
# ##### 2. 내생변수 및 중요하지 않은 변수 삭제
# ##### 3. 문자형 변수 처리 -> 숫자형 or 더미화
# ##### 4. 숫자형 변수 처리 -> 결측치 평균/중앙값으로 채우거나 nanflag 이진변수 생성
# ##### 5. 히스토그램으로 분포 확인 -> 필요시 정규화 및 클리핑

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import string
import seaborn as sns

# %%
# 컬럼과 행을 모두 다 출력할 수 있도록 설정
pd.set_option('display.max_columns', None)  # 열 생략 없이 보기
pd.set_option('display.max_rows', None)     # 행 생략 없이 보기
pd.set_option('display.max_colwidth', None) # 컬럼 너비 제한 해제

# %%
df = pd.read_csv('/Users/igangsan/Desktop/Lending-Club-Project/프로젝트/lending_club_2020_train.csv', low_memory = False)
df.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  124989905     6000.0       6000.0           6000.0   36 months    7.97%
# 1  139665484    35000.0      35000.0          35000.0   60 months   14.47%
# 2   84253847    23200.0      23200.0          23200.0   60 months   24.99%
# 3  126296074     4500.0       4500.0           4500.0   36 months    9.93%
# 4  148913312    15000.0      15000.0          15000.0   36 months   16.40%
#
#    installment grade sub_grade           emp_title emp_length home_ownership  \
# 0       187.94     A        A5             Teacher    2 years       MORTGAGE
# 1       822.95     C        C2  Product Specialist    2 years           RENT
# 2       680.82     E        E4  Production Foreman  10+ years       MORTGAGE
# 3       145.06     B        B2      Office Manager  10+ years       MORTGAGE
# 4       530.33     C        C4           Secretary  10+ years       MORTGAGE
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# 0     45000.0            Verified  Dec-2017   Fully Paid          n
# 1     94000.0     Source Verified  Sep-2018      Current          n
# 2    110000.0            Verified  Jul-2016  Charged Off          n
# 3     35000.0        Not Verified  Dec-2017      Current          n
# 4     29500.0            Verified  Apr-2019      Current          n
#
#                                                                   url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=124989905
# 1  https://lendingclub.com/browse/loanDetail.action?loan_id=139665484
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=84253847
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=126296074
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=148913312
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    554xx         MN   8.67
# 1         credit_card  Credit card refinancing    085xx         NJ  17.41
# 2  debt_consolidation       Debt consolidation    730xx         OK  34.70
# 3    home_improvement         Home improvement    339xx         FL  14.95
# 4  debt_consolidation       Debt consolidation    280xx         NC  51.26
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          1.0         Sep-2005           755.0            759.0
# 1          0.0         Dec-2002           715.0            719.0
# 2          1.0         May-1993           670.0            674.0
# 3          1.0         Nov-1995           675.0            679.0
# 4          0.0         Dec-2007           685.0            689.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                    22.0                     NaN      14.0
# 1             2.0                     NaN                     NaN       6.0
# 2             1.0                    10.0                     NaN      24.0
# 3             1.0                    22.0                     NaN      22.0
# 4             0.0                    24.0                     NaN      10.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     3090.0        14%       36.0                   w       0.00
# 1      0.0    24640.0      35.4%        8.0                   w   25993.32
# 2      0.0    16909.0      55.9%       60.0                   f       0.00
# 3      0.0     6435.0      12.1%       32.0                   w     982.41
# 4      0.0     1847.0      35.5%       21.0                   w   10910.93
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00      6718.84          6718.84          6000.00
# 1       25993.32     16430.86         16430.86          9006.68
# 2           0.00      8599.68          8599.68          1030.43
# 3         982.41      4204.26          4204.26          3517.59
# 4       10910.93      6350.29          6350.29          4089.07
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         718.84                 0.0         0.0                      0.0
# 1        7424.18                 0.0         0.0                      0.0
# 2        2309.25                 0.0      5260.0                    946.8
# 3         686.67                 0.0         0.0                      0.0
# 4        2261.22                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Apr-2020          1835.06          NaN           Apr-2020
# 1     May-2020           822.95     Jun-2020           May-2020
# 2     Dec-2016           680.82          NaN           Feb-2019
# 3     May-2020           145.06     Jun-2020           May-2020
# 4     Jun-2020             0.00     Aug-2020           May-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 764.0                760.0                         0.0
# 1                 754.0                750.0                         0.0
# 2                 639.0                635.0                         0.0
# 3                 669.0                665.0                         1.0
# 4                 669.0                665.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0        Joint App
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                         22.0          1.0       Individual
# 4                         44.0          1.0        Joint App
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0          100500.0      10.20                  Verified             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4          119500.0      15.57                  Verified             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           0.0      50054.0          1.0         10.0          3.0
# 1           0.0      58284.0          1.0          1.0          1.0
# 2           0.0     606327.0          1.0         10.0          1.0
# 3           0.0       6435.0          2.0          0.0          0.0
# 4           0.0     328452.0          1.0          7.0          4.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          3.0                 3.0       46964.0     83.0          1.0
# 1          1.0                 5.0       33644.0     96.0          0.0
# 2          2.0                10.0      277552.0     90.0          4.0
# 3          0.0                26.0           0.0      NaN          6.0
# 4          7.0                 7.0      129680.0    101.0          1.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          1.0      3090.0      64.0           22100.0     1.0          0.0
# 1          0.0      8542.0      56.0           69600.0     1.0          0.0
# 2          6.0      4698.0      85.0           30255.0     4.0          3.0
# 3         12.0      3040.0      12.0           53000.0     0.0          0.0
# 4          1.0      1847.0      98.0            5200.0     2.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           2.0                   4.0       3850.0         11910.0     20.6
# 1           2.0                   1.0       9714.0         44960.0     35.4
# 2           7.0                   8.0      25264.0          6014.0     70.4
# 3           4.0                  12.0        293.0         25751.0     16.1
# 4           6.0                   9.0      32845.0           553.0     77.0
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               147.0
# 1                       0.0          0.0                30.0
# 2                       0.0          0.0               126.0
# 3                       0.0          0.0               127.0
# 4                       0.0          0.0               129.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 135.0                   12.0             3.0       1.0
# 1                 154.0                   46.0             5.0       0.0
# 2                 277.0                    6.0             6.0       2.0
# 3                 265.0                    2.0             2.0       0.0
# 4                  54.0                    4.0             4.0       5.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  56.0                       NaN                    3.0
# 1                  46.0                       NaN                    5.0
# 2                   7.0                      10.0                    0.0
# 3                   8.0                       NaN                    2.0
# 4                  54.0                      29.0                    2.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    0.0             1.0
# 1                             NaN                    0.0             4.0
# 2                            10.0                    0.0             8.0
# 3                             NaN                    1.0             6.0
# 4                            29.0                    0.0             1.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              1.0          1.0        4.0       28.0            4.0
# 1              4.0          4.0        5.0        2.0            4.0
# 2             10.0          8.0       14.0       36.0           12.0
# 3             13.0          9.0       11.0        4.0           22.0
# 4              1.0          1.0        1.0       14.0            2.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            7.0                  1.0      14.0               0.0
# 1            5.0                  4.0       6.0               0.0
# 2           22.0                 10.0      24.0               0.0
# 3           27.0                 14.0      22.0               0.0
# 4            2.0                  1.0      10.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 4.0            97.1
# 1           0.0                 0.0                 1.0           100.0
# 2           0.0                 0.0                 5.0            94.8
# 3           0.0                 1.0                 6.0            96.8
# 4           0.0                 0.0                 6.0            78.9
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0          78611.0
# 1               0.0                   0.0        0.0         104863.0
# 2              37.5                   0.0        0.0         650914.0
# 3              22.2                   0.0        0.0          53000.0
# 4             100.0                   0.0        0.0         332978.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            50054.0         15000.0                     56511.0
# 1            58284.0         69600.0                     35000.0
# 2           294461.0         20300.0                    291465.0
# 3             6435.0         30700.0                         0.0
# 4           131527.0          2400.0                    128857.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0           3926.0                   555.0                    559.0
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4           6416.0                   655.0                    659.0
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                 Sep-2005                     0.0               0.0
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                 Dec-2007                     1.0               5.0
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0              10.0                 NaN                 10.0
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               7.0                57.6                  3.0
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    4.0                               1.0
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    4.0                               0.0
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 0.0             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 0.0             Y     CVD19SKIP
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4   REDUCED_HOURS          ACTIVE            2.0              0.0
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4            May-2020          Jul-2020                May-2020
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              2.0           0.0               ACTIVE
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                      413.83                        11025.25
#
#    hardship_last_payment_amount debt_settlement_flag
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    Y
# 3                           NaN                    N
# 4                         54.62                    N

# %%
# 종속변수 들여다보기
df['loan_status'].value_counts()

# default 변수(종속변수) 생성
df = df[df['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]
df['default'] = df['loan_status'].apply(lambda x: 1 if x in ['Charged Off', 'Default'] else 0)

# loan_status 변수 제거
df.drop(columns=['loan_status'], inplace=True)

# %%
# 2. 삭제할 변수 리스트 (84개)
drop_cols = [  # 이전에 지정한 84개
    'application_type', 'grade', 'sub_grade', 'verification_status_joint', 'hardship_loan_status', 'hardship_type', 'hardship_reason', 'hardship_status',
    'deferral_term', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date',
    'hardship_length', 'hardship_dpd', 'orig_projected_additional_accrued_interest',
    'hardship_amount', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
    'sec_app_revol_util', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high',
    'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc',
    'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',
    'sec_app_collections_12_mths_ex_med', 'annual_inc_joint', 'dti_joint', 'mths_since_last_record',
    'mths_since_recent_bc_dlq', 'mths_since_last_major_derog', 'next_pymnt_d', 'inq_fi',
    'total_cu_tl', 'emp_title', 'num_actv_bc_tl', 'hardship_flag', 'title',
    'earliest_cr_line', 'funded_amnt_inv', 'id', 'loan_amnt',
    'initial_list_status', 'int_rate', 'issue_d', 'last_credit_pull_d',
    'last_pymnt_amnt', 'out_prncp', 'out_prncp_inv', 'policy_code',
    'pymnt_plan', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int',
    'total_rec_late_fee', 'total_rec_prncp', 'url', 'zip_code', 'debt_settlement_flag',
    'desc', 'member_id', 'verified_status_joint', 'sec_app_mths_since_last_major_derog',
    'disbursement_method', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
    'settlement_amount', 'settlement_percentage', 'settlement_term', 'application type'
    # 추가 삭제(LC 대출 절차상 LC 대출 심사 후 적용되는 걸로 생각할 수 있음
    'last_fico_range_high', 'last_fico_range_low', 'verification_status'
]
df.drop(columns=[col for col in drop_cols if col in df.columns], inplace=True)

# %%
# dtype != 숫자형인 cols만 모아서 살펴보기
non_float_cols = df.select_dtypes(include = ['object', 'category', 'bool']).columns

for col in non_float_cols:
    print(f"변수명: {col}")
    print(f"고유값 수: {df[col].nunique()}")
    print(f"상위고유값: \n{df[col].value_counts(dropna=False).head(5)}\n")
# Out:
# 변수명: term
# 고유값 수: 2
# 상위고유값:
# term
# 36 months    836168
# 60 months    279988
# Name: count, dtype: int64
#
# 변수명: emp_length
# 고유값 수: 11
# 상위고유값:
# emp_length
# 10+ years    365931
# 2 years      101517
# < 1 year      92473
# 3 years       89632
# 1 year        73672
# Name: count, dtype: int64
#
# 변수명: home_ownership
# 고유값 수: 6
# 상위고유값:
# home_ownership
# MORTGAGE    550874
# RENT        441453
# OWN         122992
# ANY            721
# OTHER           88
# Name: count, dtype: int64
#
# 변수명: purpose
# 고유값 수: 14
# 상위고유값:
# purpose
# debt_consolidation    638153
# credit_card           247839
# home_improvement       74148
# other                  67931
# major_purchase         25118
# Name: count, dtype: int64
#
# 변수명: addr_state
# 고유값 수: 51
# 상위고유값:
# addr_state
# CA    158858
# TX     91698
# NY     90576
# FL     80286
# IL     43579
# Name: count, dtype: int64
#
# 변수명: revol_util
# 고유값 수: 1311
# 상위고유값:
# revol_util
# 0%     6616
# 57%    2146
# 53%    2123
# 59%    2105
# 48%    2097
# Name: count, dtype: int64
#
# 변수명: last_pymnt_d
# 고유값 수: 153
# 상위고유값:
# last_pymnt_d
# Jul-2019    24945
# Apr-2019    24794
# Feb-2019    24604
# Aug-2018    23743
# Mar-2019    23515
# Name: count, dtype: int64

# %%
## 문자형 변수 전처리
## 문자형 -> 숫자형으로 변환하는 경우는 이 단계에서 결측치 처리 안함
## 문자형 -> 더미변수로 변환하는 경우는 이 단계에서 결측치 처리함

# term: 'months' 떼고 수치화
df['term'] = df['term'].str.extract(r'(\d+)').astype(int)

# emp_length: 'years' 떼고 수치화, <1 years는 0.5로
def process_emp_length(x):
    if pd.isna(x):
        return np.nan  # 명시적으로 NaN 유지
    elif '< 1' in x:
        return 0.5
    elif '10+' in x:
        return 10.0
    else:
        extracted = pd.to_numeric(pd.Series(x).str.extract(r'(\d+)')[0], errors='coerce')
        return extracted.iloc[0]

if 'emp_length' in df.columns:
    df['emp_length'] = df['emp_length'].apply(process_emp_length)

# revol_util: % 떼고 수치화
def preprocess_revol_util(x):
    if pd.isna(x):
        return np.nan  # 그대로 유지
    x = str(x).strip().replace('%', '')
    try:
        return float(x)
    except:
        return np.nan  # 변환 실패한 경우도 NaN으로 유지

if 'revol_util' in df.columns:
    df['revol_util'] = df['revol_util'].apply(preprocess_revol_util)


# grade / sub_grade 수치화
grade_map = {k: v for v, k in enumerate(['A','B','C','D','E','F','G'], start=1)}
if 'grade' in df.columns:
    df['grade_num'] = df['grade'].map(grade_map)  # map은 NaN을 그대로 유지

if 'sub_grade' in df.columns:
    sub_grades = [f"{l}{n}" for l in string.ascii_uppercase[:7] for n in range(1, 6)]
    sub_grade_map = {k: v for v, k in enumerate(sub_grades, start=1)}
    df['sub_grade_num'] = df['sub_grade'].map(sub_grade_map)


# addr_state, home_ownership, application_type, purpose, verification_status 더미 변수 처리
# one hot encoding 과정에서 dummy_na = True를 적용해 NaN 값도 하나의 카테고리로 간주했음
# 즉, 더미화한 변수들의 결측치는 여기서 처리함

dummy_cols = ['addr_state', 'home_ownership', 'purpose', 'verification_status']
df = pd.get_dummies(df, columns=[col for col in dummy_cols if col in df.columns], 
                    dtype='uint8', dummy_na=True)

# %%
# 결측률 계산
missing_ratio = df.isnull().mean()

# 결측률이 0보다 크고 10% 미만인 변수만 선택
low_missing_cols = missing_ratio[(missing_ratio > 0) & (missing_ratio < 0.1)].index.tolist()

print(f"결측률이 10% 미만인 변수: {low_missing_cols}")
print(f"결측률이 10% 미만인 변수들의 개수:{len(low_missing_cols)}")

## 10% 미만인 경우에는 따로 nanflag 변수를 만들지 말고 분포를 확인한 뒤 평균으로 채우는 것은 어떤가요?
# Out:
# 결측률이 10% 미만인 변수: ['emp_length', 'dti', 'revol_util', 'last_pymnt_d', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'num_accts_ever_120_pd', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit']
# 결측률이 10% 미만인 변수들의 개수:40

# %%
# 결측률 10% 미만인 변수들의 분포를 보여주기

# 시각화
for col in low_missing_cols:
    plt.figure(figsize=(6,3))
    if df[col].dtype in ['float64', 'int64']:
        sns.histplot(df[col].dropna(), bins=30, kde=True)
        plt.title(f"[Numeric] Distribution of '{col}' (Missing Ratio: {missing_ratio[col]:.2%})")
    else:
        sns.countplot(x=col, data=df)
        plt.title(f"[Categorical] Countplot of '{col}' (Missing Ratio: {missing_ratio[col]:.2%})")
        plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# describe 통계량 출력
numeric_summary = df[low_missing_cols].describe().T

# 추가로 결측치 개수와 비율 추가
numeric_summary['missing_count'] = df[low_missing_cols].isnull().sum()
numeric_summary['missing_ratio'] = df[low_missing_cols].isnull().mean()

# 결과 확인
print(numeric_summary)
# Out:
#                                 count           mean            std  min  \
# emp_length                  1045848.0       5.970756       3.640562  0.5
# dti                         1115510.0      18.580972      13.369402  0.0
# revol_util                  1115316.0      50.458409      24.791103  0.0
# collections_12_mths_ex_med  1116118.0       0.017874       0.150068  0.0
# tot_coll_amt                1075752.0     232.234467    5476.644978  0.0
# tot_cur_bal                 1075752.0  142393.461711  159600.497675  0.0
# total_rev_hi_lim            1075752.0   33758.033310   35330.017739  0.0
# acc_open_past_24mths        1087855.0       4.652558       3.193029  0.0
# avg_cur_bal                 1075723.0   13596.028969   16492.265236  0.0
# bc_open_to_buy              1075645.0   11040.482590   16307.954920  0.0
# bc_util                     1075064.0      58.172741      28.717244  0.0
# chargeoff_within_12_mths    1116118.0       0.008854       0.107176  0.0
# mo_sin_old_il_acct          1043662.0     125.557811      52.892606  0.0
# mo_sin_old_rev_tl_op        1075751.0     180.600414      95.833260  1.0
# mo_sin_rcnt_rev_tl_op       1075751.0      13.514757      16.872640  0.0
# mo_sin_rcnt_tl              1075752.0       7.995183       8.873052  0.0
# mort_acc                    1087855.0       1.606512       1.944409  0.0
# mths_since_recent_bc        1076413.0      24.156308      31.382542  0.0
# num_accts_ever_120_pd       1075752.0       0.509442       1.353754  0.0
# num_actv_rev_tl             1075752.0       5.594182       3.339358  0.0
# num_bc_sats                 1082727.0       4.747838       3.002977  0.0
# num_bc_tl                   1075752.0       7.871803       4.748161  0.0
# num_il_tl                   1075752.0       8.560169       7.408470  0.0
# num_op_rev_tl               1075752.0       8.248751       4.634076  0.0
# num_rev_accts               1075751.0      14.260890       8.098082  0.0
# num_rev_tl_bal_gt_0         1075752.0       5.542664       3.251575  0.0
# num_sats                    1082727.0      11.627193       5.576646  0.0
# num_tl_120dpd_2m            1034976.0       0.000719       0.028649  0.0
# num_tl_30dpd                1075752.0       0.003204       0.059994  0.0
# num_tl_90g_dpd_24m          1075752.0       0.086026       0.502528  0.0
# num_tl_op_past_12m          1075752.0       2.151239       1.848153  0.0
# pct_tl_nvr_dlq              1075652.0      94.135033       8.910306  0.0
# percent_bc_gt_75            1075371.0      43.045942      36.186280  0.0
# pub_rec_bankruptcies        1115717.0       0.133017       0.373091  0.0
# tax_liens                   1116127.0       0.049510       0.396504  0.0
# tot_hi_cred_lim             1075752.0  177150.045339  180192.302739  0.0
# total_bal_ex_mort           1087855.0   50442.154458   48859.118306  0.0
# total_bc_limit              1087855.0   22502.366439   22432.273340  0.0
# total_il_high_credit_limit  1075752.0   43193.655871   44347.984402  0.0
#
#                                  25%        50%        75%        max  \
# emp_length                      2.00       6.00      10.00       10.0
# dti                            11.82      17.72      24.29      999.0
# revol_util                     31.60      50.50      69.60      366.6
# collections_12_mths_ex_med      0.00       0.00       0.00       20.0
# tot_coll_amt                    0.00       0.00       0.00  5252395.0
# tot_cur_bal                 29293.00   80298.50  212946.00  5445012.0
# total_rev_hi_lim            14400.00   24800.00   42000.00  9999999.0
# acc_open_past_24mths            2.00       4.00       6.00       61.0
# avg_cur_bal                  3097.00    7419.00   18835.00   752994.0
# bc_open_to_buy               1629.00    5182.00   13612.00   605996.0
# bc_util                        35.60      60.80      83.60      318.2
# chargeoff_within_12_mths        0.00       0.00       0.00        9.0
# mo_sin_old_il_acct             96.00     129.00     153.00      999.0
# mo_sin_old_rev_tl_op          116.00     163.00     230.00      909.0
# mo_sin_rcnt_rev_tl_op           4.00       8.00      16.00      438.0
# mo_sin_rcnt_tl                  3.00       6.00      10.00      382.0
# mort_acc                        0.00       1.00       3.00       51.0
# mths_since_recent_bc            6.00      14.00      29.00      656.0
# num_accts_ever_120_pd           0.00       0.00       0.00       45.0
# num_actv_rev_tl                 3.00       5.00       7.00       72.0
# num_bc_sats                     3.00       4.00       6.00       63.0
# num_bc_tl                       4.00       7.00      10.00       89.0
# num_il_tl                       4.00       7.00      11.00      138.0
# num_op_rev_tl                   5.00       7.00      10.00       83.0
# num_rev_accts                   8.00      13.00      18.00      121.0
# num_rev_tl_bal_gt_0             3.00       5.00       7.00       65.0
# num_sats                        8.00      11.00      14.00       90.0
# num_tl_120dpd_2m                0.00       0.00       0.00        6.0
# num_tl_30dpd                    0.00       0.00       0.00        4.0
# num_tl_90g_dpd_24m              0.00       0.00       0.00       42.0
# num_tl_op_past_12m              1.00       2.00       3.00       30.0
# pct_tl_nvr_dlq                 91.30      98.50     100.00      100.0
# percent_bc_gt_75                0.00      40.00      75.00      100.0
# pub_rec_bankruptcies            0.00       0.00       0.00       12.0
# tax_liens                       0.00       0.00       0.00       85.0
# tot_hi_cred_lim             50403.00  114066.00  256076.00  9999999.0
# total_bal_ex_mort           20849.00   37608.00   63628.00  2644442.0
# total_bc_limit               8000.00   15700.00   29350.00  1090700.0
# total_il_high_credit_limit  15000.00   32398.00   58022.00  2101913.0
#
#                             missing_count  missing_ratio
# emp_length                          70308       0.062991
# dti                                   646       0.000579
# revol_util                            840       0.000753
# collections_12_mths_ex_med             38       0.000034
# tot_coll_amt                        40404       0.036199
# tot_cur_bal                         40404       0.036199
# total_rev_hi_lim                    40404       0.036199
# acc_open_past_24mths                28301       0.025356
# avg_cur_bal                         40433       0.036225
# bc_open_to_buy                      40511       0.036295
# bc_util                             41092       0.036816
# chargeoff_within_12_mths               38       0.000034
# mo_sin_old_il_acct                  72494       0.064950
# mo_sin_old_rev_tl_op                40405       0.036200
# mo_sin_rcnt_rev_tl_op               40405       0.036200
# mo_sin_rcnt_tl                      40404       0.036199
# mort_acc                            28301       0.025356
# mths_since_recent_bc                39743       0.035607
# num_accts_ever_120_pd               40404       0.036199
# num_actv_rev_tl                     40404       0.036199
# num_bc_sats                         33429       0.029950
# num_bc_tl                           40404       0.036199
# num_il_tl                           40404       0.036199
# num_op_rev_tl                       40404       0.036199
# num_rev_accts                       40405       0.036200
# num_rev_tl_bal_gt_0                 40404       0.036199
# num_sats                            33429       0.029950
# num_tl_120dpd_2m                    81180       0.072732
# num_tl_30dpd                        40404       0.036199
# num_tl_90g_dpd_24m                  40404       0.036199
# num_tl_op_past_12m                  40404       0.036199
# pct_tl_nvr_dlq                      40504       0.036289
# percent_bc_gt_75                    40785       0.036541
# pub_rec_bankruptcies                  439       0.000393
# tax_liens                              29       0.000026
# tot_hi_cred_lim                     40404       0.036199
# total_bal_ex_mort                   28301       0.025356
# total_bc_limit                      28301       0.025356
# total_il_high_credit_limit          40404       0.036199

# %%
# 결측률 < 10%인 변수들 전처리

# emp_length: 결측치 = 0 + missing label
df['emp_length_missing'] = df['emp_length'].isnull().astype(int)
df['emp_length'] = df['emp_length'].fillna(0)

# percent_bc_gt_75: 결측치 0 + missing label
df['percent_bc_gt_75_missing'] = df['percent_bc_gt_75'].isnull().astype(int)
df['percent_bc_gt_75'] = df['percent_bc_gt_75'].fillna(0)

# 0으로 채운 변수들
fillna0_cols = ['collections_12_mths_ex_med', 'tot_coll_amt', 'chargeoff_within_12_mths', 'mo_sin_old_il_acct' ]
df[fillna0_cols] = df[fillna0_cols].fillna(0)

# 중앙값으로 채운 변수들
median_replacement_cols = ['tot_cur_bal', 'total_rev_hi_lim', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 
                           'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op',
                          'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'num_accts_ever_120_pd', 'num_actv_rev_tl', 
                           'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 
                           'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 
                           'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 
                           'total_bc_limit', 'total_il_high_credit_limit'] 
df[median_replacement_cols] = df[median_replacement_cols].fillna(df[median_replacement_cols].median())

# %%
# 결측률 > 10%인 변수들 살펴보기

# 1. 전체 숫자형 변수 목록
numeric_cols = df.select_dtypes(include='number').columns

# 2. 결측률이 10% 미만인 변수 제외
remaining_numeric_cols = list(set(numeric_cols) - set(low_missing_cols))

# 3. 더미 변수(0과 1만 있는 변수) 제외
non_dummy_numeric_cols = [
    col for col in remaining_numeric_cols
    if df[col].dropna().nunique() > 2  # 고유값 개수가 2개 이하인 변수는 제외 (0, 1 또는 상수)
]

print(f"더미 변수 제외한 숫자형 변수 목록: {non_dummy_numeric_cols}")
print(f"개수: {len(non_dummy_numeric_cols)}")
# Out:
# 더미 변수 제외한 숫자형 변수 목록: ['funded_amnt', 'delinq_amnt', 'inq_last_12m', 'fico_range_low', 'mths_since_last_delinq', 'all_util', 'collection_recovery_fee', 'fico_range_high', 'open_act_il', 'mths_since_recent_revol_delinq', 'delinq_2yrs', 'annual_inc', 'pub_rec', 'open_acc_6m', 'recoveries', 'total_acc', 'mths_since_recent_inq', 'open_acc', 'last_fico_range_high', 'mths_since_rcnt_il', 'open_rv_24m', 'revol_bal', 'total_bal_il', 'inq_last_6mths', 'open_il_12m', 'max_bal_bc', 'il_util', 'acc_now_delinq', 'installment', 'open_il_24m', 'open_rv_12m']
# 개수: 31

# %%
# 결측률 10% 이상이 변수들은 일괄적으로 결측값 0 대체+missing indicator 추가
for col in non_dummy_numeric_cols:
    # 결측 여부 표시하는 변수 생성 (1: 결측, 0: 결측 아님)
    df[f'{col}_missing'] = df[col].isnull().astype(int)

    # 결측값을 0으로 대체
    df[col] = df[col].fillna(0)
# Out:
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)
# /var/folders/h1/2kvn4fr11vn6f3469636zhp40000gn/T/ipykernel_3125/3904844.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_missing'] = df[col].isnull().astype(int)

# %%
# 1) 로그 변환할 연속형 변수 목록
log_cols = [
    'annual_inc', 'dti', 'max_bal_bc', 'total_rev_hi_lim', 'avg_cur_bal',
    'bc_open_to_buy', 'delinq_amnt', 'tot_hi_cred_lim',
    'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal'
]

# 결측 → 중앙값 대체 (이미 처리된 경우에는 생략해도 됩니다)
for col in log_cols:
    if df[col].isnull().any():
        df[col] = df[col].fillna(df[col].median())

# 로그 변환
for col in log_cols:
    df[col] = np.log1p(df[col])

# 2) 바이너리로 바꿀 카운트형 변수 목록
bin_cols = [
    'delinq_2yrs', 'pub_rec', 'collections_12_mths_ex_med',
    'acc_now_delinq', 'tot_coll_amt', 'chargeoff_within_12_mths',
    'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
    'pub_rec_bankruptcies', 'tax_liens'
]

# 1 이상을 1로
for col in bin_cols:
    df[col] = df[col].fillna(0)           # NA → 0
    df[col] = (df[col] >= 1).astype(int) # 0 ⇒ 0, 1 이상 ⇒ 1

# %%
# 바뀐 변수들의 분포를 보여주기

# 1) 연속형 변수 히스토그램
for col in log_cols:
    plt.figure()
    plt.hist(df[col].dropna(), bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# 2) 이진화 변수 막대차트
for col in bin_cols:
    counts = df[col].value_counts().sort_index()
    plt.figure()
    plt.bar(counts.index.astype(str), counts.values)
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtype}")
# Out:
# funded_amnt: float64
# term: int64
# installment: float64
# emp_length: float64
# annual_inc: float64
# dti: float64
# delinq_2yrs: int64
# fico_range_low: float64
# fico_range_high: float64
# inq_last_6mths: float64
# mths_since_last_delinq: float64
# open_acc: float64
# pub_rec: int64
# revol_bal: float64
# revol_util: float64
# total_acc: float64
# recoveries: float64
# collection_recovery_fee: float64
# last_pymnt_d: object
# last_fico_range_high: float64
# collections_12_mths_ex_med: int64
# acc_now_delinq: int64
# tot_coll_amt: int64
# tot_cur_bal: float64
# open_acc_6m: float64
# open_act_il: float64
# open_il_12m: float64
# open_il_24m: float64
# mths_since_rcnt_il: float64
# total_bal_il: float64
# il_util: float64
# open_rv_12m: float64
# open_rv_24m: float64
# max_bal_bc: float64
# all_util: float64
# total_rev_hi_lim: float64
# inq_last_12m: float64
# acc_open_past_24mths: float64
# avg_cur_bal: float64
# bc_open_to_buy: float64
# bc_util: float64
# chargeoff_within_12_mths: int64
# delinq_amnt: float64
# mo_sin_old_il_acct: float64
# mo_sin_old_rev_tl_op: float64
# mo_sin_rcnt_rev_tl_op: float64
# mo_sin_rcnt_tl: float64
# mort_acc: float64
# mths_since_recent_bc: float64
# mths_since_recent_inq: float64
# mths_since_recent_revol_delinq: float64
# num_accts_ever_120_pd: float64
# num_actv_rev_tl: float64
# num_bc_sats: float64
# num_bc_tl: float64
# num_il_tl: float64
# num_op_rev_tl: float64
# num_rev_accts: float64
# num_rev_tl_bal_gt_0: float64
# num_sats: float64
# num_tl_120dpd_2m: int64
# num_tl_30dpd: int64
# num_tl_90g_dpd_24m: int64
# num_tl_op_past_12m: float64
# pct_tl_nvr_dlq: float64
# percent_bc_gt_75: float64
# pub_rec_bankruptcies: int64
# tax_liens: int64
# tot_hi_cred_lim: float64
# total_bal_ex_mort: float64
# total_bc_limit: float64
# total_il_high_credit_limit: float64
# default: int64
# addr_state_AK: uint8
# addr_state_AL: uint8
# addr_state_AR: uint8
# addr_state_AZ: uint8
# addr_state_CA: uint8
# addr_state_CO: uint8
# addr_state_CT: uint8
# addr_state_DC: uint8
# addr_state_DE: uint8
# addr_state_FL: uint8
# addr_state_GA: uint8
# addr_state_HI: uint8
# addr_state_IA: uint8
# addr_state_ID: uint8
# addr_state_IL: uint8
# addr_state_IN: uint8
# addr_state_KS: uint8
# addr_state_KY: uint8
# addr_state_LA: uint8
# addr_state_MA: uint8
# addr_state_MD: uint8
# addr_state_ME: uint8
# addr_state_MI: uint8
# addr_state_MN: uint8
# addr_state_MO: uint8
# addr_state_MS: uint8
# addr_state_MT: uint8
# addr_state_NC: uint8
# addr_state_ND: uint8
# addr_state_NE: uint8
# addr_state_NH: uint8
# addr_state_NJ: uint8
# addr_state_NM: uint8
# addr_state_NV: uint8
# addr_state_NY: uint8
# addr_state_OH: uint8
# addr_state_OK: uint8
# addr_state_OR: uint8
# addr_state_PA: uint8
# addr_state_RI: uint8
# addr_state_SC: uint8
# addr_state_SD: uint8
# addr_state_TN: uint8
# addr_state_TX: uint8
# addr_state_UT: uint8
# addr_state_VA: uint8
# addr_state_VT: uint8
# addr_state_WA: uint8
# addr_state_WI: uint8
# addr_state_WV: uint8
# addr_state_WY: uint8
# addr_state_nan: uint8
# home_ownership_ANY: uint8
# home_ownership_MORTGAGE: uint8
# home_ownership_NONE: uint8
# home_ownership_OTHER: uint8
# home_ownership_OWN: uint8
# home_ownership_RENT: uint8
# home_ownership_nan: uint8
# purpose_car: uint8
# purpose_credit_card: uint8
# purpose_debt_consolidation: uint8
# purpose_educational: uint8
# purpose_home_improvement: uint8
# purpose_house: uint8
# purpose_major_purchase: uint8
# purpose_medical: uint8
# purpose_moving: uint8
# purpose_other: uint8
# purpose_renewable_energy: uint8
# purpose_small_business: uint8
# purpose_vacation: uint8
# purpose_wedding: uint8
# purpose_nan: uint8
# emp_length_missing: int64
# percent_bc_gt_75_missing: int64
# funded_amnt_missing: int64
# delinq_amnt_missing: int64
# inq_last_12m_missing: int64
# fico_range_low_missing: int64
# mths_since_last_delinq_missing: int64
# all_util_missing: int64
# collection_recovery_fee_missing: int64
# fico_range_high_missing: int64
# open_act_il_missing: int64
# mths_since_recent_revol_delinq_missing: int64
# delinq_2yrs_missing: int64
# annual_inc_missing: int64
# pub_rec_missing: int64
# open_acc_6m_missing: int64
# recoveries_missing: int64
# total_acc_missing: int64
# mths_since_recent_inq_missing: int64
# open_acc_missing: int64
# last_fico_range_high_missing: int64
# mths_since_rcnt_il_missing: int64
# open_rv_24m_missing: int64
# revol_bal_missing: int64
# total_bal_il_missing: int64
# inq_last_6mths_missing: int64
# open_il_12m_missing: int64
# max_bal_bc_missing: int64
# il_util_missing: int64
# acc_now_delinq_missing: int64
# installment_missing: int64
# open_il_24m_missing: int64
# open_rv_12m_missing: int64

# %%
print(f"변수 총 개수: {len(df.columns)}")
# Out:
# 변수 총 개수: 180

# %%
IRR_subset = df[['term', 'last_pymnt_d', 'installment', 'funded_amnt', 'recoveries', 'collection_recovery_fee']]
target = df['default']
print(IRR_subset.head(20))
# Out:
#     term last_pymnt_d  installment  funded_amnt  recoveries  \
# 0     36     Apr-2020       187.94       6000.0        0.00
# 2     60     Dec-2016       680.82      23200.0     5260.00
# 5     36     Aug-2019       494.55      16000.0      936.75
# 6     36     Mar-2019       146.10       4500.0        0.00
# 7     36     Oct-2018       645.25      20000.0        0.00
# 8     60     Jun-2019       482.17      19000.0        0.00
# 12    36     Mar-2018      1114.76      30000.0     2722.00
# 13    60     Aug-2019       342.56      16000.0        0.00
# 14    36     Mar-2020       190.09       6025.0        0.00
# 16    36     Jun-2018       542.22      15000.0        0.00
# 17    36     Jun-2015        36.28       1000.0        0.00
# 18    36     Feb-2017       166.05       5000.0        0.00
# 19    36     Apr-2019       486.98      15000.0        0.00
# 20    60     Aug-2019       306.64      12500.0        0.00
# 22    36     Feb-2018       775.94      25000.0        0.00
# 23    60     Oct-2018       790.82      35000.0        0.00
# 24    36     Apr-2019       139.10       4500.0        0.00
# 25    60     Jun-2017       489.85      22975.0        0.00
# 26    36     Jun-2019       884.46      26000.0        0.00
# 27    36     Jun-2019       178.49       5000.0        0.00
#
#     collection_recovery_fee
# 0                     0.000
# 2                   946.800
# 5                   168.615
# 6                     0.000
# 7                     0.000
# 8                     0.000
# 12                  489.960
# 13                    0.000
# 14                    0.000
# 16                    0.000
# 17                    0.000
# 18                    0.000
# 19                    0.000
# 20                    0.000
# 22                    0.000
# 23                    0.000
# 24                    0.000
# 25                    0.000
# 26                    0.000
# 27                    0.000

# %%
# 전처리된 파일 저장
df.to_csv('preprocessed_data_ver.2.2.(IRR+LOG+BINARY)csv', index=False)
